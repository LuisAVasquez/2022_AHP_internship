# %% [markdown]
# # For each letter, extract the Nominal groups and put them in the database

# %% [markdown]
# ## Getting the letters:
#
# Run this query on the Henri Poincare Correspondence SPARQL endpoint [http://tomcat.henripoincare.fr/fuseki/#/dataset/hp_corpus/query](http://tomcat.henripoincare.fr/fuseki/#/dataset/hp_corpus/query), and save the result to a file `00_queryResults_transcriptions.csv` inside a `dataframes` folder next to this notebook

# %%
# transcriptions with their language

"""
PREFIX ahpo: <http://e-hp.ahp-numerique.fr/ahpo#>
        PREFIX dcterms: <http://purl.org/dc/terms/>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX o:     <http://omeka.org/s/vocabs/o#>
PREFIX o-cnt: <http://www.w3.org/2011/content#>
 SELECT DISTINCT ?letter ?media ?language ?transcription WHERE { 
  #?lettre ahpo:sentBy <http://henripoincare.fr/api/items/843>.
  #?lettre ahpo:writingDate ?date .
  #?lettre ahpo:transcription ?trans.
  # ?letter a ahpo:Letter.
  # ?letter o:media ?media . 
  # ?media o-cnt:chars ?transcription.
  OPTIONAL{ ?letter ahpo:language ?language}

} ORDERBY ?language

""";

# %% [markdown]
# ## Importing the tools

# %%
from AHPNLP.tokenization.tokenization import Tokenizer

# I will use the french tokenizer for all the letter, because that's what the 
# recommendation system uses  at the end of the day
nominal_groups_french_tokenizer = Tokenizer(language = "french", nominal_groups= True)

# %%
import pandas as pd
import os
#notebooks/05/create_tokens_triples.ipynb
#notebooks/05/dataframes/00_queryResults_transcriptions.csv
df = pd.read_csv(os.path.join("dataframes","00_queryResults_transcriptions.csv"))

# %%
df.columns
# Out:
# Index(['letter', 'media', 'language', 'transcription'], dtype='object')

# %%
len(df)
# Out:
# 1944

# %%
df = df.dropna(subset=['transcription'])
len(df)
# Out:
# 1942

# %% [markdown]
# Clean the transcriptions

# %%
from AHPNLP.utilities.utilities import get_clean_transcription
df['clean_transcription'] = df['transcription'].apply(get_clean_transcription)

# %% [markdown]
# Compute the nominal groups

# %%
# %%time
# preprocessing
df['normalized_nominal_groups'] = df['clean_transcription'].apply(
    lambda st: set(
        nominal_groups_french_tokenizer.tokenize_for_nominal_groups(
           nominal_groups_french_tokenizer.spacy_pipeline(st),
           normalized_form=True
        )

    )
)
# Out:
# CPU times: user 3min 20s, sys: 698 ms, total: 3min 21s
# Wall time: 3min 26s

# %%
df['normalized_nominal_groups']
# Out:
# 0       {charles brisse, henri poincaré, albert badour...
# 1       {succès fou, timeo davaos, mlle clémence et de...
# 2       {frère belleville, école central de art et man...
# 3       {gouvernement jules dufaure, mahon et son chef...
# 4       {rinck attribu, unité monétaire, élie rinck, f...
#                               ...
# 1939    {välja mellan, icke torde kunna, till kongl, h...
# 1940    {afhandling med, physique mathématique, hans m...
# 1941    {newton insåg först att centrifulgalkraften ko...
# 1942    {sferiska elektronerna, vidsträckt användning,...
# 1943    {henri poincaré, fredholm att, måtte tilldelas...
# Name: normalized_nominal_groups, Length: 1942, dtype: object

# %%
nominal_groups_french_tokenizer.tokenize_for_nominal_groups(
           nominal_groups_french_tokenizer.spacy_pipeline("fonctions fuchsiennes"),
           normalized_form=True
        )
# Out:
# ['fonction fuchsienne']

# %% [markdown]
# ### Note:
#
# "fuchsienne" is not recognized by the french tokenizer, thus, we have to manually normalize it by applying these replacements in sequence.
#
# 1. "fuchsiennes" $\to$ "fuchsien"
# 2. "fuchsiens" $\to$ "fuchsien"
# 3. "fuchsienne" $\to$ "fuchsien"
# 4. "fuchsien" $\to$ "fuchsienne"

# %%
#This is the definition used in the package.
"""
def normalise_fuchsien(st):
    return st.replace(
                "fuchsiennes", "fuchsien"
            ).replace(
                "fuchsiens", "fuchsien"
            ).replace(
                "fuchsienne", "fuchsien"
            ).replace(
                "fuchsien", "fuchsienne"
            ).replace(
                "groupe fuchsienne", "groupe fuchsien" #only case when it is in masculine
            )
"""

# %% [markdown]
# ## Quick test

# %%
fuchsien_nominal_groups = []

for nominal_groups in df['normalized_nominal_groups']:
    for nominal_group in nominal_groups:
        if "fuchs" in nominal_group:
            fuchsien_nominal_groups.append(nominal_group)

print(len(fuchsien_nominal_groups))
fuchsien_nominal_groups
# Out:
# 56
# ['fonction zetafuchsienne',
#  'ihre definition der fuchsienne',
#  'fonction fuchsienne',
#  'gekannten funktionen fallen also nicht unter ihre definition der fuchsienne',
#  'herren fuchs',
#  'groupe fuchsien',
#  'fonction fuchsienne',
#  'groupe fuchsien',
#  'fonction zétafuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'groupe fuchsien',
#  'idée succincte sur le fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fuch et le dénomination de fonction fuchsienne',
#  'fonction fuchsienne',
#  'fuchsienne noch',
#  'werde ich weder von fuchsienne noch kleinéenne gebrauch',
#  'fonction fuchsienne',
#  'fuchs in',
#  'série relatif à fonction zétafuchsienne',
#  'fonction fuchsienne',
#  'fonction zétafuchsienne',
#  'edmond fuchs',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction thêtafuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'groupe fuchsien',
#  'fonction zétafuchsienne',
#  'fonction fuchsienne',
#  'étude si remarquable sur le fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'note sur le propriété de fonction fuchsienne',
#  'monsieur fuchs',
#  'fonction zeta ou thetafuchsienne',
#  'fonction fuchsienne',
#  'fonction analogue à fonction zétafuchsienne et thétafuchsienne',
#  'fonction fuchsienne',
#  'fonction fuchsienne',
#  'fuchsiska thetafunktioner och',
#  'fuchsiska zetafunktioner',
#  'fuchsiska funktioner']

# %% [markdown]
# ## Triple template

# %% [markdown]
# Triples look like this:
# ```
# <http://henripoincare.fr/api/items/12531> ahpo:test "test"@en .
# ```

# %%
turtle_file_name = "normalized_nominal_groups_2.ttl"

property_name = "ahpo:hasNominalGroupInContent2"
triple_format = '<{letter_id}> '+property_name+' "{value}" .'
triple_format
# Out:
# '<{letter_id}> ahpo:hasNominalGroupInContent2 "{value}" .'

# %%
# preface:
preface = """@prefix :             <http://data.kasabi.com/dataset/italy/schema/> .
@prefix ahpo:         <http://e-hp.ahp-numerique.fr/ahpo#> .
@prefix ahpot:        <http://henripoincare.fr/ahpot> .

"""

# %%
triples = []

for _, row in df.iterrows():
    nominal_groups = row['normalized_nominal_groups']
    letter = row['letter']
    for token in nominal_groups:
        if "\\" not in token:  
            # we have to remove a special character that breaks the syntax
            triple = triple_format.format(
                letter_id = letter, 
                value = token
                )
            triples.append(triple)

# %%
len(triples)
# Out:
# 23098

# %%
triples
# Out:
# ['<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "albert badoureau" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "euphrasie launois" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "octave barré" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "heure chacun" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "capitaine issu" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "eugène brisse" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "capitaine mahieu" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "grand-mère maternel" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "charles eugène pinat" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "jean baptiste henry millot" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "antoinette poincaré" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "hélène antoinette poincaré" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "albert gille" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "grand-père paternel" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "pitaine bouquin" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "événement extraordinaire" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "monsieur brisse" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "gabriel davau" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "responsabilité spécial" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "ancien me avoir" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "charles brisse" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "henri poincaré" .',
#  '<http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "jacques nicolas poincaré" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "oncle adrien" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "abord lundi" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "succès fou" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "assistant ce" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "henri poincaré" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "école sainte-geneviève" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "adrien launois" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "timeo davaos et dona ferente" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "planche topo de ancien" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "tien moi" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "timeo davaos" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "mlle clémence et de xardel" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "mlle clémence" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "cheval de troie" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "terme couvert" .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "code x." .',
#  '<http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "électeur inscrit" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville registres" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école agronomique de paris" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "société français" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste gérald" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "académie de science" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "octave barré" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "charles henry" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école de mine" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "œuvre de laguerre" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "muséum de histoire naturel" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste dumas" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "frère belleville" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "paul émile haag" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "histoire naturel" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "bureau de longitude" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "temps référence" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "léon poincaré" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "ossian bonnet" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "abord répétiteur à le école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "frédéric toussaint dubost" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "laguerre ami de le oncle" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "eugène rouché" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "début décembre" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "lettre suivant" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "félix leblanc" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "société français de chimie" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "mauvais colle" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "michel chasles" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "chimie analytique à le école central de art et manufacture" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "louis joseph gay" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "clément lemoine" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "analyse il y avoir deux colleur" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "louis comon" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école agronomique" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école central de art et manufacture" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "edmond frémy" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "antonin poincaré" .',
#  '<http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "hermann laurent" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "j.-n. jeanneney" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "étudiant issu de institution catholique" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ministre de le intérieur" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "union républicain" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "chahut infernal" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "prière public" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "martin de auray" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "guerre de" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "républicanisme modérer" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "droite légitimiste" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "président de le république" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mathématique spécial" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "comte de chambord" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "attitude bienveillant" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "félix de temple de le croix" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "valeur religieux" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "liberté public" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "baragnon parl" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "lettre de habitant de nancy à monsieur thiers" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "réputation national" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "jules dufaure" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "séance très chiqu" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "gouvernement jules dufaure" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "discours très chic" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "voix poser" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "frère louis" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "union de droite" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "type très chic principalement un banc où il y avoir cinq espèce de paysan richard et bigot" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ville encore occupé" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "alphonse alfred haentjens" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "rang républicain" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "plan horizontal" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "influenfe dangereux" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "nomma ministre" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "léon gambetta être dans le année" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "début décembre" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "terme populaire" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "louis buffet" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "politique farouchement" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "joseph martin de auray" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "adolphe thier" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "monsieur thiers" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "auteur révoqu" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "buffet le arrête" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mahon et son chef de gouvernement albert de broglie" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "napoléon iii" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "carrière politique" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "forme nécessaire" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "niveau national" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mariage civil" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "georges halphen" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "effet splendide" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "enterrement civil" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "comité de neuf" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "circ circulaire" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "voix glapissant" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "milieu politique" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "proposition relatif au rétablissement de le monarchie" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "journal de lyon" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "chambord a. robert" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "henri dufaur de gavardie" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "albert de broglie" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "moment cruel" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "emmanuel ruault" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "lettre précédent" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "assemblée national" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ministère de le intérieur" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "léon gambetta" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "presse républicain" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "pierre baragnon" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "commission mixte" .',
#  '<http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ordre moral" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "amédée mannheim qui être en charger de cours de stéréotomie lorsque poincaré être à le école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "étude théorique" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "exemple littéraire" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "palais royal" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "géométrie descriptif" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "voie hiérarchique" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sale admini" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "second empire" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sainte barbe" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "rinck attribu" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "pierre magne" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "françois jean charles paignon" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "jargon militaire" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "amédée mannheim" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "bidot sous prétexte que on me avoir à dîner" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "école de mine de baptiser le nouveau promotion" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sens figuré" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "grognement significatif" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville" .',
#  '<http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "unité monétaire" .',
#  '<http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur olleris" .',
#  '<http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur valette" .',
#  '<http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur olleris et chez monsieur valette" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "adolphe thiers" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "académie français" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société national" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "conseil rectoral" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "émile ollivier" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société de agriculture" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "orateur parlementaire et publicist" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société national et central de agriculture de france" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "autrement dire" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "sully prudhomme" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "sully prudhomme et à m." .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "université catholique" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "cher confrère" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "emile ollivier" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "conseil rectoral de mon université" .',
#  '<http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "institut catholique de paris" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "société scientifique" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "henri barboux" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "comité de rédaction de le" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "académie de science" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "secrétaire perpétuel" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "sully prudhomme" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "revue de deux monde" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "institut de france" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "costa de beauregard" .',
#  '<http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "papier antique" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "conversation français" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "confusion amusant" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "moyenne général" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "homme rougeaud" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "françois i" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "bataille de crécy" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "guerre de cent an" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "henri albert herdner" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "oeil effaré" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "traduction de le phrase" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "martin de marie" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "ville de" .',
#  '<http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "moitié bas" .',
#  '<http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "albert gille" .',
#  '<http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "bergeval être un petit localité" .',
#  '<http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "province belge" .',
#  '<http://henripoincare.fr/api/items/12917> ahpo:hasNominalGroupInContent2 "gonzalve olleris" .',
#  '<http://henripoincare.fr/api/items/12917> ahpo:hasNominalGroupInContent2 "léon antoine genay" .',
#  '<http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "brouillard incomparable" .',
#  '<http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "note définitive de dessin" .',
#  '<http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "billy que je avoir trouver" .',
#  '<http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "roger berment" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "échec consid" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "bois de boulogne" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "henri courbebaisse et armand lesueur" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "armand lesueur" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "georges antoine henri courbebaisse" .',
#  '<http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "georges antoine" .',
#  '<http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "congé limité" .',
#  '<http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "lettre suivant" .',
#  '<http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "plocq dans ce lettr" .',
#  '<http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "albert gille" .',
#  '<http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "jardin de acclimatation" .',
#  '<http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "intérêt particulier" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "alphonse herpin" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "pharmacien nancéien" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "somme relativement important à le époque" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "paul émile dreyfus" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "osip ivanovitch somov" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "jacques edmond laflaquière" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "marie rené" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville" .',
#  '<http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "voyage se être passer sans aucun" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "charles garnier" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "opéra garnier" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "marie louis alexandre garnier" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "opéra de paris" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "octave barré" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "roger berment" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "jacques antoine charles bresse" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "marie louis" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "lycée louis-le-grand" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "alexandre garnier" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "paul burani" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "promos promotion" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "carrière civil" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "antonin louis" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jean durand" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "thomas sauvage" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "gabriel de lurieu" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "emmanuel chabrier" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles alfred oppermann" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "pierre nicolas belin de launay" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "beau cadeau" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "paul verlaine" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "affaire imprévu" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "joseph arnaud" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles auguste" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jules belin de launay" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "urbain rouccou" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "sire de fisch" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "plock arriv salle" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles küss" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "moustache énorme" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "napoléon iii" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "type étranger" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "tartarie e. chabrier" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "manière assez violent" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "monsieur rinck" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "chanson satirique" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "napoléon iii et le famille impérial" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "rien de tout" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jean durand de villers" .',
#  '<http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "théâtre de le ambigu" .',
#  '<http://henripoincare.fr/api/items/13014> ahpo:hasNominalGroupInContent2 "lévy adrien" .',
#  '<http://henripoincare.fr/api/items/13018> ahpo:hasNominalGroupInContent2 "brice malade et en robe de chambre" .',
#  '<http://henripoincare.fr/api/items/13018> ahpo:hasNominalGroupInContent2 "julie lhôte" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "françois jules benjamin" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "élisabeth matuszynski" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "évocation très vivant" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "jean monestier" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "voyage très agréable" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "mlle clarinval" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "paul émile dreyfus" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "curée registre" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "eugène weiss" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "eugène édouard baillot" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "louise jacquinet" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "probablement marie" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "émile zola" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "reste rien" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "mlle norberg" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "monsieur rinck" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "astro astronomie" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "pont de austerlitz" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "monsieur brice" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "boulevard montmartre" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "album luxueux" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "fils unique" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "bientôt odieux" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "méthode pédagogique savant" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur pauly qui dîner chez lui" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur o. kerrins" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur pauly" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "magnifique collection" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "heure et demi" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "élie rinck et son famille" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "aline boutroux" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "état plus rassurant de même rôti" .',
#  '<http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "valette et chez monsieur o. kerrins que je n\' avoir trouver" .',
#  '<http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "bataille où nous avoir dîner avec élie" .',
#  '<http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "octave barré" .',
#  '<http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "établissement essentiel" .',
#  '<http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "louis émile pugnière" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école primaire supérieur de nancy" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "compagnie saint-gobain puis le soudier de le meurthe" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "monsieur rinck où être présent" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "augustin renaud" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "clément colson" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "chimie minéral" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "émile françois maurice girod de le ain" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "bois de boulogne" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "laboratoire central" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "légion de honneur" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "régénération national" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école primaire" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "connaissance nancéien" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "paul schützenberger" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école professionnel" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école polytechnique" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "aline boutroux" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "brevet primaire et supérieur" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "compagnie saint-gobain" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "charles riquier" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "rambaud qui me emmener de abord" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "registres de étudiant de le" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "réseau polytechnicien" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "nombre chercher" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "monsieur rinck" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "prix lacaze" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "vitesse v." .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "soudier de le meurthe" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "albert colson" .',
#  '<http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "grâce à registre matricule" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "astro astronomie" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "général de barail" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "chose très rigolo" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "colle samedi" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "françois charles de barail" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "amphi fusil et le mardi" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "élie rinck" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "jean baptiste charles marie joseph" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "mercredi prochain" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "adolphe amoureux" .',
#  '<http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "laurent rollet" .',
#  '<http://henripoincare.fr/api/items/14963> ahpo:hasNominalGroupInContent2 "lettre précédent" .',
#  '<http://henripoincare.fr/api/items/14963> ahpo:hasNominalGroupInContent2 "étienne poste" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "immense palai" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "lanterne vénitien" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "voix splendide" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "opéra comique" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "chose gigonnaire" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "fumoir seul" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "résultat indécis" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "talent tout à fait supérieur" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "paul victor villiet" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "splendeur scénique" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "rôle plus insignifiant" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "noce de figaro" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "boul mich" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "soufflot n" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "effet il falloir descendre à le fontaine pour en juger le effet" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "alexandre robinet" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "grâce à ce fumiste" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "boul mich boulevard saint-michel" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "alexandre robinet de le serve" .',
#  '<http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "marche turque" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "cahiers de séminaire de histoire" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie philosophique qu\' on être toujours libre de passer" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mathematische annalen" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "public français" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "théorie général" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie philosophique" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "acta mathematica" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "soin possible" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "meilleur traval" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "allgemeinen mannigfaltigkeitslehre" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "tournure philosophique" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "travail antérieur" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mathématicien allemand" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mémoire français" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "gösta mittag" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "saint sulpice" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "expression embarrassant" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "monsieur mittag" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "forme vide" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "article paraître à mathematische annalen entre" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "éditeur parisien" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "culture allemand" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "cahier de séminaire de histoire de mathématique dugac" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "contribution à le théorie de ensemble" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "madame poincaré" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "abbé dargent" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "exemple précis" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "garantie scientifique" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "esprit français" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "connaissance antérieure" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "beau travail" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "dossier poincaré" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "sentiment très sérieux" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie mathématique" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "grundlagen einer allgemeinen mannigfaltigkeit" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "beau mémoir" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "lecteur français" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "acta un" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "traduction français" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "charles hermite" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mémoire important" .',
#  '<http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "fois philosophique et mathématique" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "rechnen wir darauf" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "august gleichzeitig" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "stabilität nicht langer" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "bald andere" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "grübchen nicht stabil sein kann" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "bitte schließen" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "hoffnung ihrer" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "versammlungen zwischen" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "eine diesbezüglich" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wenn die" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "betracht kommen" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "poincaré annehmen" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "herr professor" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "endlich einmal wieder einen hervorragenden" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "meinen besten" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "gelegenheit auch" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "ende der birne erzeugt" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "vermutung nahe" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "selbst wenn die ersten stabil sind" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "vorstand der astron" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "mitte zu sehn" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "deformation bereits" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "resultat verändert" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "finger reicht" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "frage der stabilität der birnfigur" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "abelfeier sicher" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "gesellschaft seit" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wirklichkeit das grübchen" .',
#  '<http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "anzeige an prof" .',
# ...
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "studien an" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ersuchen mich" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "kennen lernen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "aufenthalt in" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "darstellung einer icosaedertheorie" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "hochgeehrter herr" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "übergang von" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "gedenke oft" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "einteilungen nur beiläufig behandelt sind und ich auf beispiele gekommen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "münchen vor" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "stets bin" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ihren aufsatz" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ihnen in paris gefunden" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "publikation in den acta zusammenhängt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "paris aufgesucht" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "functionen handelt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "weierstraß und" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "studium zugehöriger functionen handelt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "hören zu lassen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "frau gemahlin" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "funktionen zu denen einer" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "klein geht" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "erinnerung halt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "notiz über meine eigenen studien" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "weggang professor" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ihrem aufsatz" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "stets bin ich" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "jahres noch" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "einteilungen nur beiläufig behandelt sind" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "münchen angenommen hab" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "übersenden erlaube" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "zusammenhang mettre den gleichungen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "frau gemahlin besten zu empfehlen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ihnen noch" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "paris hab" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "herbst ihren aufsatz" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "übersendung ich besten nachträglich danke" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "wenn mein" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "mitteilung machen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "glück gehabt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "bericht ihnen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "satz das jeder gruppe linearer substitutionen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "nämlich di" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "wollte ich doch" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "nachträglich danke" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "ausbildung der techniker handelt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "mich freuen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "satz anknüpfen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "denke daß" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "beispiele gekommen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "vergleich bedeutender ist" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "acta zusammenhängt" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "reihe von speziellen formulierungen" .',
#  '<http://henripoincare.fr/api/items/10706> ahpo:hasNominalGroupInContent2 "welche sich" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "british und der american" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "serie von ereignissen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "arbeiten hat kommen lassen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "einmal mein" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "dank für" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "mich besten" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "tätigkeit an der schule" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "irrthum betreff" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "bitte best" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "jahre wechsel" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "monaten so freundlich waren" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "muse zum arbeiten" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "studium der dortigen universitätsverhältniße betrifft" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "freundlich waren" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "mathematics besprochen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "nehmen sie besten" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "jetzt eine dreimonatlich" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "universitätsverhältniße betrifft" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "eine militärische dienstleistung" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "treiben kennen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "eindrücken zurückkam" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "irrthum betreff jener gebietseinteilungen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "studium ihrer arbeit gemacht" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "menschlichen standpunkt" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "treiben kennen zu lernen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "gedenke gern" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "jetzt ist" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "arbeit gemacht" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "jetzt ist der horizont wieder etwas enger gezogen" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "ihre letzte freundliche" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "wißenschaftlichen standpunkt" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "hätte schon lange" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "freundlichen stunden" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "umsiedlung nach" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "brief den sie" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "eine ganz" .',
#  '<http://henripoincare.fr/api/items/10707> ahpo:hasNominalGroupInContent2 "reise nach amerika" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "ende nächster woche dauert" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "zusendung ihrer letzten arbeit" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "formulierungen ihre" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "abschnitte allgemein die" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "raum auszudehnen" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "arbeit mich" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "lange verzögerung" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "zeit finden" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "société übernommenen" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "mitteilung entnehmen" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "noch bitten" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "ihnen zuzusenden mir erlaube" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "formulierung die fläche" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "teil ihrer arbeit findet" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "auch wirklich" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "beziehung die sich ja auch in dem geometrischen" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "dann will ich auch wirklich zeit finden" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "appell und picard" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "gesicht bekam" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "abschnitt bezieht sich" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "eine curvensystems" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "werden sie" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "hoffe jetzt" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "augenblicklich stecken" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "unsere gemeinschaftlichen" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "dann will" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "zettel für" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "zeit zu finden" .',
#  '<http://henripoincare.fr/api/items/10708> ahpo:hasNominalGroupInContent2 "betrifft in ihrem ersten abschnitte allgemein die beziehung der besonderen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "ihre hochgeehrt" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "arbeiten für das" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "untersuchungen über analysis situ beschäftigt" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "lange verzögerung gütig entschuldigen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "crelle vol" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "nämlich flächen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "eine vorlesung" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "meinem seminar" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "modulfunction entstehend" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "reellen bez" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "wird besonder" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "frau gemahlin und an unsere gemeinschaftlichen bekannten" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "welche den reellen bez" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "bitte bester" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "intereßirt mich sehr" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "augenblicklich bin ich" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "welche in den vielen geschäftlichen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "function über der ebene x" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "intereßirt mich" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "weiterführung jener untersuchungen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "analysis situ" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "frau gemahlin" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "hochverehrter herr" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "ihnen zu schluß de sommer" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "gelegenheit desselben auch ihre schönen untersuchungen" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "gelegenheit desselben auch ihre" .',
#  '<http://henripoincare.fr/api/items/10709> ahpo:hasNominalGroupInContent2 "welche in den vielen" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "dank aussprechen für die belehrung" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "theorie zu berechtigen" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "welche der helmholtz\' schen" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "seien sie" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "anstosse unterbrochen" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "ihrem ergebensten" .',
#  '<http://henripoincare.fr/api/items/10781> ahpo:hasNominalGroupInContent2 "wäre mir im höchsten" .',
#  ...]

# %%
turtle_file_content = preface + "\n".join(triples)
print(turtle_file_content)
# Out:
# @prefix :             <http://data.kasabi.com/dataset/italy/schema/> .
# @prefix ahpo:         <http://e-hp.ahp-numerique.fr/ahpo#> .
# @prefix ahpot:        <http://henripoincare.fr/ahpot> .
#
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "albert badoureau" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "euphrasie launois" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "octave barré" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "heure chacun" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "capitaine issu" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "eugène brisse" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "capitaine mahieu" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "grand-mère maternel" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "charles eugène pinat" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "jean baptiste henry millot" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "antoinette poincaré" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "hélène antoinette poincaré" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "albert gille" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "grand-père paternel" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "pitaine bouquin" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "événement extraordinaire" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "monsieur brisse" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "gabriel davau" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "responsabilité spécial" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "ancien me avoir" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "charles brisse" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "henri poincaré" .
# <http://henripoincare.fr/api/items/12531> ahpo:hasNominalGroupInContent2 "jacques nicolas poincaré" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "oncle adrien" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "abord lundi" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "succès fou" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "assistant ce" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "henri poincaré" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "école sainte-geneviève" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "adrien launois" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "timeo davaos et dona ferente" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "planche topo de ancien" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "tien moi" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "timeo davaos" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "mlle clémence et de xardel" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "mlle clémence" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "cheval de troie" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "terme couvert" .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "code x." .
# <http://henripoincare.fr/api/items/12546> ahpo:hasNominalGroupInContent2 "électeur inscrit" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville registres" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école agronomique de paris" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "société français" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste gérald" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "académie de science" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "octave barré" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "charles henry" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école de mine" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "œuvre de laguerre" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "muséum de histoire naturel" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "jean-baptiste dumas" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "frère belleville" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "paul émile haag" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "histoire naturel" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "bureau de longitude" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "temps référence" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "léon poincaré" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "ossian bonnet" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "abord répétiteur à le école polytechnique" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "frédéric toussaint dubost" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "laguerre ami de le oncle" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "eugène rouché" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "début décembre" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "lettre suivant" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "félix leblanc" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "société français de chimie" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "mauvais colle" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "michel chasles" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "chimie analytique à le école central de art et manufacture" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "louis joseph gay" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "clément lemoine" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "analyse il y avoir deux colleur" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "louis comon" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école agronomique" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "école central de art et manufacture" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "edmond frémy" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "antonin poincaré" .
# <http://henripoincare.fr/api/items/12596> ahpo:hasNominalGroupInContent2 "hermann laurent" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "j.-n. jeanneney" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "étudiant issu de institution catholique" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ministre de le intérieur" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "union républicain" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "chahut infernal" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "prière public" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "martin de auray" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "guerre de" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "républicanisme modérer" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "droite légitimiste" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "président de le république" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mathématique spécial" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "comte de chambord" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "attitude bienveillant" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "félix de temple de le croix" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "valeur religieux" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "liberté public" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "baragnon parl" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "lettre de habitant de nancy à monsieur thiers" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "réputation national" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "jules dufaure" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "séance très chiqu" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "gouvernement jules dufaure" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "discours très chic" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "voix poser" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "frère louis" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "union de droite" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "type très chic principalement un banc où il y avoir cinq espèce de paysan richard et bigot" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ville encore occupé" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "alphonse alfred haentjens" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "rang républicain" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "plan horizontal" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "influenfe dangereux" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "nomma ministre" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "léon gambetta être dans le année" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "début décembre" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "terme populaire" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "louis buffet" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "politique farouchement" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "joseph martin de auray" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "adolphe thier" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "monsieur thiers" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "auteur révoqu" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "buffet le arrête" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mahon et son chef de gouvernement albert de broglie" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "napoléon iii" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "carrière politique" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "forme nécessaire" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "niveau national" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "mariage civil" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "georges halphen" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "effet splendide" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "enterrement civil" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "comité de neuf" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "circ circulaire" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "voix glapissant" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "milieu politique" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "proposition relatif au rétablissement de le monarchie" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "journal de lyon" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "chambord a. robert" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "henri dufaur de gavardie" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "albert de broglie" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "moment cruel" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "emmanuel ruault" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "lettre précédent" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "assemblée national" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ministère de le intérieur" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "léon gambetta" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "presse républicain" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "pierre baragnon" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "commission mixte" .
# <http://henripoincare.fr/api/items/12614> ahpo:hasNominalGroupInContent2 "ordre moral" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "amédée mannheim qui être en charger de cours de stéréotomie lorsque poincaré être à le école polytechnique" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "étude théorique" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "exemple littéraire" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "palais royal" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "géométrie descriptif" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "voie hiérarchique" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sale admini" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "second empire" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sainte barbe" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "rinck attribu" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "pierre magne" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "françois jean charles paignon" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "jargon militaire" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "amédée mannheim" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "bidot sous prétexte que on me avoir à dîner" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "école de mine de baptiser le nouveau promotion" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "sens figuré" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "grognement significatif" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville" .
# <http://henripoincare.fr/api/items/12625> ahpo:hasNominalGroupInContent2 "unité monétaire" .
# <http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur olleris" .
# <http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur valette" .
# <http://henripoincare.fr/api/items/12630> ahpo:hasNominalGroupInContent2 "monsieur olleris et chez monsieur valette" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "adolphe thiers" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "académie français" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société national" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "conseil rectoral" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "émile ollivier" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société de agriculture" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "orateur parlementaire et publicist" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "société national et central de agriculture de france" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "autrement dire" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "sully prudhomme" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "sully prudhomme et à m." .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "université catholique" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "cher confrère" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "emile ollivier" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "conseil rectoral de mon université" .
# <http://henripoincare.fr/api/items/12890> ahpo:hasNominalGroupInContent2 "institut catholique de paris" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "société scientifique" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "henri barboux" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "comité de rédaction de le" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "académie de science" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "secrétaire perpétuel" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "sully prudhomme" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "revue de deux monde" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "institut de france" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "costa de beauregard" .
# <http://henripoincare.fr/api/items/12897> ahpo:hasNominalGroupInContent2 "papier antique" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "conversation français" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "confusion amusant" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "moyenne général" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "homme rougeaud" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "françois i" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "bataille de crécy" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "guerre de cent an" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "henri albert herdner" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "oeil effaré" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "traduction de le phrase" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "martin de marie" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "ville de" .
# <http://henripoincare.fr/api/items/12908> ahpo:hasNominalGroupInContent2 "moitié bas" .
# <http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "albert gille" .
# <http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "bergeval être un petit localité" .
# <http://henripoincare.fr/api/items/12913> ahpo:hasNominalGroupInContent2 "province belge" .
# <http://henripoincare.fr/api/items/12917> ahpo:hasNominalGroupInContent2 "gonzalve olleris" .
# <http://henripoincare.fr/api/items/12917> ahpo:hasNominalGroupInContent2 "léon antoine genay" .
# <http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "brouillard incomparable" .
# <http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "note définitive de dessin" .
# <http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "billy que je avoir trouver" .
# <http://henripoincare.fr/api/items/12922> ahpo:hasNominalGroupInContent2 "roger berment" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "échec consid" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "bois de boulogne" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "henri courbebaisse et armand lesueur" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "armand lesueur" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "georges antoine henri courbebaisse" .
# <http://henripoincare.fr/api/items/12927> ahpo:hasNominalGroupInContent2 "georges antoine" .
# <http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "congé limité" .
# <http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "lettre suivant" .
# <http://henripoincare.fr/api/items/12928> ahpo:hasNominalGroupInContent2 "plocq dans ce lettr" .
# <http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "albert gille" .
# <http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "jardin de acclimatation" .
# <http://henripoincare.fr/api/items/12952> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "intérêt particulier" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "alphonse herpin" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "pharmacien nancéien" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "somme relativement important à le époque" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "paul émile dreyfus" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "osip ivanovitch somov" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "jacques edmond laflaquière" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "marie rené" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "jean-baptiste belleville" .
# <http://henripoincare.fr/api/items/12954> ahpo:hasNominalGroupInContent2 "voyage se être passer sans aucun" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "charles garnier" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "opéra garnier" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "marie louis alexandre garnier" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "opéra de paris" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "octave barré" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "roger berment" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "jacques antoine charles bresse" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "marie louis" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "lycée louis-le-grand" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/13000> ahpo:hasNominalGroupInContent2 "alexandre garnier" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "paul burani" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "promos promotion" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "carrière civil" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "antonin louis" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jean durand" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "thomas sauvage" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "gabriel de lurieu" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "emmanuel chabrier" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles alfred oppermann" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "pierre nicolas belin de launay" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "beau cadeau" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "paul verlaine" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "affaire imprévu" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "joseph arnaud" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles auguste" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jules belin de launay" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "urbain rouccou" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "sire de fisch" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "plock arriv salle" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "charles küss" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "moustache énorme" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "napoléon iii" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "type étranger" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "tartarie e. chabrier" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "manière assez violent" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "monsieur rinck" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "chanson satirique" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "napoléon iii et le famille impérial" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "rien de tout" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "jean durand de villers" .
# <http://henripoincare.fr/api/items/13005> ahpo:hasNominalGroupInContent2 "théâtre de le ambigu" .
# <http://henripoincare.fr/api/items/13014> ahpo:hasNominalGroupInContent2 "lévy adrien" .
# <http://henripoincare.fr/api/items/13018> ahpo:hasNominalGroupInContent2 "brice malade et en robe de chambre" .
# <http://henripoincare.fr/api/items/13018> ahpo:hasNominalGroupInContent2 "julie lhôte" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "françois jules benjamin" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "élisabeth matuszynski" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "évocation très vivant" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "jean monestier" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "voyage très agréable" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "mlle clarinval" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "paul émile dreyfus" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "curée registre" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "eugène weiss" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "eugène édouard baillot" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "louise jacquinet" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "probablement marie" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "émile zola" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "reste rien" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/13022> ahpo:hasNominalGroupInContent2 "mlle norberg" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "monsieur rinck" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "astro astronomie" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "pont de austerlitz" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "monsieur brice" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13045> ahpo:hasNominalGroupInContent2 "boulevard montmartre" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "album luxueux" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "fils unique" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "bientôt odieux" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "méthode pédagogique savant" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur pauly qui dîner chez lui" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur o. kerrins" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "monsieur pauly" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "magnifique collection" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "heure et demi" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "élie rinck et son famille" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "aline boutroux" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "état plus rassurant de même rôti" .
# <http://henripoincare.fr/api/items/13058> ahpo:hasNominalGroupInContent2 "valette et chez monsieur o. kerrins que je n' avoir trouver" .
# <http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "bataille où nous avoir dîner avec élie" .
# <http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "octave barré" .
# <http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "établissement essentiel" .
# <http://henripoincare.fr/api/items/13063> ahpo:hasNominalGroupInContent2 "louis émile pugnière" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école primaire supérieur de nancy" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "compagnie saint-gobain puis le soudier de le meurthe" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "monsieur rinck où être présent" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "augustin renaud" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "clément colson" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "chimie minéral" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "émile françois maurice girod de le ain" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "bois de boulogne" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "laboratoire central" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "légion de honneur" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "régénération national" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école primaire" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "connaissance nancéien" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "paul schützenberger" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école professionnel" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "école polytechnique" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "aline boutroux" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "brevet primaire et supérieur" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "compagnie saint-gobain" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "charles riquier" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "rambaud qui me emmener de abord" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "registres de étudiant de le" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "réseau polytechnicien" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "nombre chercher" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "monsieur rinck" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "prix lacaze" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "vitesse v." .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "soudier de le meurthe" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "albert colson" .
# <http://henripoincare.fr/api/items/13069> ahpo:hasNominalGroupInContent2 "grâce à registre matricule" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "astro astronomie" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "général de barail" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "chose très rigolo" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "colle samedi" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "françois charles de barail" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "amphi fusil et le mardi" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "élie rinck" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "jean baptiste charles marie joseph" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "mercredi prochain" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "adolphe amoureux" .
# <http://henripoincare.fr/api/items/14462> ahpo:hasNominalGroupInContent2 "laurent rollet" .
# <http://henripoincare.fr/api/items/14963> ahpo:hasNominalGroupInContent2 "lettre précédent" .
# <http://henripoincare.fr/api/items/14963> ahpo:hasNominalGroupInContent2 "étienne poste" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "immense palai" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "lanterne vénitien" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "voix splendide" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "opéra comique" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "chose gigonnaire" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "fumoir seul" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "résultat indécis" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "talent tout à fait supérieur" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "paul victor villiet" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "splendeur scénique" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "rôle plus insignifiant" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "noce de figaro" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "boul mich" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "soufflot n" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "effet il falloir descendre à le fontaine pour en juger le effet" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "alexandre robinet" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "grâce à ce fumiste" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "boul mich boulevard saint-michel" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "alexandre robinet de le serve" .
# <http://henripoincare.fr/api/items/15187> ahpo:hasNominalGroupInContent2 "marche turque" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "cahiers de séminaire de histoire" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie philosophique qu' on être toujours libre de passer" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mathematische annalen" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "public français" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "théorie général" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie philosophique" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "acta mathematica" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "soin possible" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "meilleur traval" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "allgemeinen mannigfaltigkeitslehre" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "tournure philosophique" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "travail antérieur" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mathématicien allemand" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mémoire français" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "gösta mittag" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "saint sulpice" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "expression embarrassant" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "monsieur mittag" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "forme vide" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "article paraître à mathematische annalen entre" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "éditeur parisien" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "culture allemand" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "cahier de séminaire de histoire de mathématique dugac" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "contribution à le théorie de ensemble" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "madame poincaré" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "abbé dargent" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "exemple précis" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "garantie scientifique" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "esprit français" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "connaissance antérieure" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "beau travail" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "dossier poincaré" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "sentiment très sérieux" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "partie mathématique" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "grundlagen einer allgemeinen mannigfaltigkeit" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "beau mémoir" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "lecteur français" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "acta un" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "traduction français" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "charles hermite" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "mémoire important" .
# <http://henripoincare.fr/api/items/15899> ahpo:hasNominalGroupInContent2 "fois philosophique et mathématique" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "rechnen wir darauf" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "august gleichzeitig" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "stabilität nicht langer" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "bald andere" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "grübchen nicht stabil sein kann" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "bitte schließen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "hoffnung ihrer" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "versammlungen zwischen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "eine diesbezüglich" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wenn die" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "betracht kommen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "poincaré annehmen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "herr professor" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "endlich einmal wieder einen hervorragenden" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "meinen besten" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "gelegenheit auch" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "ende der birne erzeugt" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "vermutung nahe" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "selbst wenn die ersten stabil sind" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "vorstand der astron" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "mitte zu sehn" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "deformation bereits" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "resultat verändert" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "finger reicht" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "frage der stabilität der birnfigur" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "abelfeier sicher" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "gesellschaft seit" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wirklichkeit das grübchen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "anzeige an prof" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "ganz ergebener" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "werden wir" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "vortrag über ein ihnen" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "zufrieden sein" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "august zur" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "august zur astronomenversammlung" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "stunde zu rangieren" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wenn ich richtig vorausseh" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "wenigsten kann" .
# <http://henripoincare.fr/api/items/17450> ahpo:hasNominalGroupInContent2 "dank für die übersendung der arbeiten über die" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "wünsche fügen" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "arbeiten über das apioid" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "weitere über ihre ergebnisse zu hören" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "ihre ergebnisse zu hören" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "machen zu dürfen" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "keine vorschrift" .
# <http://henripoincare.fr/api/items/17452> ahpo:hasNominalGroupInContent2 "herr professor" .
# ...
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "först strängt" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "korthet antyda" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "formen af ringen sektion" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "relativ jemnvigt" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "utan utåt" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "resultaten af attraktionen och centrifugalkraften" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "oändligt stor radi" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "rotationshastigheten öka" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "till kongl" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "dylika serier äro" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "poincaré har i" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "hvilken partiklar" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "gång två oliker serier" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "till erhålland af" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "början uppstält" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "hade ick" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "vetenskapsakademien nobelkomité för fysik" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "philosophical transactions" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "derför föreslå" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "bevi att" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "jacobiska ellipsoiderner" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "symmetriska i förhållande till ett plan" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "vara satisfierad för att stabilitet skall ega rum" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "comptes rendre" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "päronformade jemnvigtsfigurerna" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "acta matematica" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "kelvin hade" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "formen af" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "olika jemnvigtsfigurer" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "vara riktad ick inåt" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "början har" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "hvari han" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "oändligt tunn cirkulär" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "laurins ellipsoid och jacobi ellipsoid med tre oliker axlar voro läng de enda kända jemnvigtsfigurerna" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "bulletin astronomique" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "henri poincaré" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "vinkelrätt mot des riktining" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "skilda från" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "lord kelvin" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "hvari han visar" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "stabil och" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "nobelpriset för" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "öfvergår till" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "afplattad rotationsellipsoid" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "stockholm den" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "ingen annan" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "blott två symmetriplan" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "till frågan" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "henri poincaré i paris" .
# <http://henripoincare.fr/api/items/17745> ahpo:hasNominalGroupInContent2 "möjliga bilda liniära serier" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "upptäckten af den retarderad potentialen gjorde" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré har i sin afhandling" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "förklaringen var" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "skenbart oändliga fortplantningshastighet ha fått sin naturliger förklaring" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "någon ändring vid" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "sferiska elektronerna förkorta i rörelsen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "hastigheterna skull" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "äfven sedan michelson" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "hittoff och" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "bidraga till" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré gifvit" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "ljuset aberration" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "afhandling lyckat aflägsna" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "gravitationsvågen lemnar den" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "öfverraskande resultat" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "riemann göra" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "elektromagnetisk natur" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "genom detter" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "elektronteorin ett" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "till exempel" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vunna med den strängaste skärpa" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "henri poincaré i paris" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré har" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "éclairage électrique" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vågor vid" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "skenbart oändliga fortplantningshastighet ha fått" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "afstämda trådlöser telegrafin som förra året belönades med nobelpris i f." .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "största praktiska konseqvenser" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "ledde detta ick till något resultat" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "bidraga till ett" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "erhålle som" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vågen när den" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "särskildt meddelandener i t." .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "tomen af comptes rendre" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vetenskapsakademien nobelkomité för fysik" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vunna med" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "katodstrålarne banor" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "någon ändring" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "lumière électrique" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "katodstrålarna banor" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "sferiska elektronerna" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "transversala axlarna" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré gaf" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "öfrigt oförändrad" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "använding utaf" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "någon ändlig fortplantningshastighet" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "hvilket fenomen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "oscillation hertzien" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré först" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "blott af kropparna stälning" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "nobelpriset i fysik för" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "förhållande till" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vidsträckt användning" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "strängaste skärpa" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "förhållande till etern" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "visat att denner eqvation har" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré för" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "oriktigt sätt" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "blott tog i" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "visat des stora" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "omöjligheten att" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "comptes rendre" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "jorden rundt" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "serie vigtiga" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "icke elektromagnetisk" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "maxwells eqvationer för vektor potentialen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "nobelpris i f." .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "särskildt hvilka" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "sechs vorlesungen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "särskilda volymselementen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "oscillationerna förmå" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "attraktionen består" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "teoretiska behandlingen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "genom fenomenet" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "poincaré lemnat bidrag" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "utgör grundvalen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "ifrån detter resultat har" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "någon ändlig" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "skenbara rörelsen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "största praktiska" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "vidare har denna förklaring haft" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "fullt sammanhängand" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "öfrigt bildar" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "medför vigtiga" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "ligne munie" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "någon relativ hastighet" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "kropparna stälning" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "denna förklaring innebär motsägelser och osannolikheter och har rönt mycken opposition såsom en konstlad nödfallsutväg" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "attraherande kroppen" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "elektronerna dynamik" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "härigenom gifven till de af" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "matematiska teorier" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "till kongl" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "période variable" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "afstämda trådlöser" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "laplace had" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "comptes rendus" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "elektronerna sammandragning" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "henri poincaré" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "hvars arbete" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "materien rörels" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "stockholm den" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "betraktande elektriska kraften och" .
# <http://henripoincare.fr/api/items/17751> ahpo:hasNominalGroupInContent2 "till exempel gravitationen" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "måtte tilldelas henri poincaré" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "henri poincaré" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "härmed har jag äran anhålla" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "fredholm att" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "physique mathématique" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "darboux och" .
# <http://henripoincare.fr/api/items/17763> ahpo:hasNominalGroupInContent2 "équation différentiel" .

# %%
with open(turtle_file_name,'w') as file:
    file.write(turtle_file_content)
